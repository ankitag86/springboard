# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitag86/springboard/blob/ankitag86-pandas/Sweetviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sweetviz

# %%
import pandas as pd
import sweetviz as sv
penguins = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/penguins_cleaned.csv')

# %%
#Seperating X and Y
X = penguins.drop('species', axis=1)
y = penguins['species']
X
# Out:
#         island  bill_length_mm  ...  body_mass_g     sex
# 0    Torgersen            39.1  ...         3750    male
# 1    Torgersen            39.5  ...         3800  female
# 2    Torgersen            40.3  ...         3250  female
# 3    Torgersen            36.7  ...         3450  female
# 4    Torgersen            39.3  ...         3650    male
# ..         ...             ...  ...          ...     ...
# 328      Dream            55.8  ...         4000    male
# 329      Dream            43.5  ...         3400  female
# 330      Dream            49.6  ...         3775    male
# 331      Dream            50.8  ...         4100    male
# 332      Dream            50.2  ...         3775  female
#
# [333 rows x 6 columns]

# %%
penguins
# Out:
#        species     island  ...  body_mass_g     sex
# 0       Adelie  Torgersen  ...         3750    male
# 1       Adelie  Torgersen  ...         3800  female
# 2       Adelie  Torgersen  ...         3250  female
# 3       Adelie  Torgersen  ...         3450  female
# 4       Adelie  Torgersen  ...         3650    male
# ..         ...        ...  ...          ...     ...
# 328  Chinstrap      Dream  ...         4000    male
# 329  Chinstrap      Dream  ...         3400  female
# 330  Chinstrap      Dream  ...         3775    male
# 331  Chinstrap      Dream  ...         4100    male
# 332  Chinstrap      Dream  ...         3775  female
#
# [333 rows x 7 columns]

# %%
analyze_report = sv.analyze(penguins)
analyze_report.show_html('analyze.html', open_browser = False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report analyze.html was generated.

# %%
#Visualization
import IPython
IPython.display.HTML(filename='analyze.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# 3. Side by side Comparison of Train vs Test Set

# %% [markdown]
# 3.1 Data split using 80/20 Slit Ratio

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train
# Out:
#         island  bill_length_mm  ...  body_mass_g     sex
# 73   Torgersen            42.1  ...         4000    male
# 180     Biscoe            48.4  ...         5400    male
# 206     Biscoe            46.2  ...         5300    male
# 197     Biscoe            45.1  ...         4400  female
# 116  Torgersen            40.2  ...         3450  female
# ..         ...             ...  ...          ...     ...
# 23      Biscoe            37.9  ...         3150  female
# 91       Dream            40.3  ...         4350    male
# 285      Dream            42.4  ...         3600  female
# 104     Biscoe            38.1  ...         3825  female
# 257     Biscoe            46.2  ...         4375  female
#
# [266 rows x 6 columns]

# %%
X_test
# Out:
#      island  bill_length_mm  ...  body_mass_g     sex
# 26    Dream            37.2  ...         3900    male
# 94   Biscoe            35.0  ...         3725  female
# 320   Dream            52.2  ...         3450    male
# 145   Dream            41.5  ...         4000    male
# 269   Dream            52.7  ...         3725    male
# ..      ...             ...  ...          ...     ...
# 292   Dream            49.5  ...         3800    male
# 154  Biscoe            43.3  ...         4400  female
# 92    Dream            33.1  ...         2900  female
# 139   Dream            39.0  ...         3650    male
# 261  Biscoe            46.8  ...         4850  female
#
# [67 rows x 6 columns]

# %% [markdown]
# 3.2 Comparison Report

# %%
import sweetviz as sv
compare_report = sv.compare([X_train, "Train"], [X_test, "Test"])
compare_report.show_html('compare.html', open_browser = False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report compare.html was generated.

# %%
import IPython
IPython.display.HTML(filename='compare.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
# %pip install numpy==1.24.3 --force-reinstall
# Out:
# ...
#   Using cached numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ERROR: Operation cancelled by user
